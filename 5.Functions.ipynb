# %%
def BMI():
    BMI=int(input("Enter BMI index: "))
    if (BMI<18.5):
        print("Underweight")
        message="Underweight"
    elif(BMI<24.9):
        print("Normal")
        message="Normal"
    else:
        print("Overweight")
        message="Overweight"
    return message

# %%
bmi=BMI()
# Out:
# Enter BMI index:  24
# Normal

# %%
def addition(num1,num2):
    add=num1+num2
    return add

# %%
addition(1,2)
# Out:
# 3
