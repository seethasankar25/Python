# %%
#from python filename import the class (classname)
from multipleFunction import multipleFunctions

# %%
multipleFunctions.BMI()
# Out:
# Enter BMI index:  34
# Overweight
# 'Overweight'

# %%
multipleFunctions.oddEven()
# Out:
# Enter number:  23
# Odd number
# 'Odd number'
